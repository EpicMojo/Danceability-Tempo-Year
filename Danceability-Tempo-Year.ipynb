# %%
import pandas as pd
pd.__version__
# Out:
# '1.4.2'

# %%
import numpy as np
np.__version__
# Out:
# '1.21.5'

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\justb\Downloads\Spotify_Project\collected_data\tracks_features.csv')

# %% [markdown]
# This is where the file was read into the notebook

# %%
df.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# ...

# %% [markdown]
# This presents the first 5 songs with each attribute

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# This shows what data frame type the file is in

# %%
df.describe()
# Out:
#        track_number   disc_number  danceability        energy           key  \
# count  1.204025e+06  1.204025e+06  1.204025e+06  1.204025e+06  1.204025e+06
# mean   7.656352e+00  1.055906e+00  4.930565e-01  5.095363e-01  5.194151e+00
# std    5.994977e+00  2.953752e-01  1.896694e-01  2.946839e-01  3.536731e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.000000e+00  1.000000e+00  3.560000e-01  2.520000e-01  2.000000e+00
# 50%    7.000000e+00  1.000000e+00  5.010000e-01  5.240000e-01  5.000000e+00
# 75%    1.000000e+01  1.000000e+00  6.330000e-01  7.660000e-01  8.000000e+00
# max    5.000000e+01  1.300000e+01  1.000000e+00  1.000000e+00  1.100000e+01
#
#            loudness          mode   speechiness  acousticness  \
# count  1.204025e+06  1.204025e+06  1.204025e+06  1.204025e+06
# mean  -1.180870e+01  6.714595e-01  8.438219e-02  4.467511e-01
# std    6.982132e+00  4.696827e-01  1.159914e-01  3.852014e-01
# ...

# %%
df['tempo']
# Out:
# 0          117.906
# 1          103.680
# 2          149.749
# 3           96.752
# 4          127.059
#             ...
# 1204020    159.586
# 1204021    121.980
# 1204022    121.996
# 1204023    124.986
# 1204024    117.991
# Name: tempo, Length: 1204025, dtype: float64

# %% [markdown]
# This shows the 'tempo' attribute of each song

# %%
df['danceability']
# Out:
# 0          0.470
# 1          0.599
# 2          0.315
# 3          0.440
# 4          0.426
#            ...
# 1204020    0.264
# 1204021    0.796
# 1204022    0.785
# 1204023    0.665
# 1204024    0.736
# Name: danceability, Length: 1204025, dtype: float64

# %% [markdown]
# This shows the 'danceability' attribute of each song

# %%
df[df['year'] < 1905]
# Out:
#                             id                    name          album  \
# 450071  3xPatAieFSuGIuQfHMDvSw           Arabian Waltz  Arabian Waltz
# 450072  5vpx0WtYVtKOFu4V65NkUi  Dreams Of A Dying City  Arabian Waltz
# 450073  0G7vBbeWCcRISsHwcivFgl    Ornette Never Sleeps  Arabian Waltz
# 450074  6YjrfDT2TPp6pflsCSBHPH                Georgina  Arabian Waltz
# 450075  2Nq317w5G1gmuhilTCiiqR                 No Visa  Arabian Waltz
# 450076  6PzeE7vvynVguz04STK6RL          The Pain After  Arabian Waltz
# 459980  4DZ63H1bRMmiTcXiQhERxv                 Catania      Al-Jadida
# 459981  6QqZn286ICbbhTjNBPlgNY                  Nashwa      Al-Jadida
# 459982  5Mw5YkQkHuGqYQL5XMrUOI   An Evening With Jerry      Al-Jadida
# 459983  4SNCi2xa3dkM0HPTQ1AFBP  When The Lights Go Out      Al-Jadida
# 459984  1XEbjKZygiDllK5WpEB73O            Story Teller      Al-Jadida
# 459985  5V4pmHLdq0fhEw5DjkaW2w     Ornette Never Sleps      Al-Jadida
# ...

# %% [markdown]
# This is how I found the earliest year of songs collected

# %%
df[df['year'] > 2019]
# Out:
#                              id                                   name  \
# 446      78XK5PDIKWiDKcgiLl1x0o                     Still Disappointed
# 544      788iAD4CWTasYlX3msWCvk                           God Finds Us
# 545      0ePi0Pj92VxX4iJbD59ekS                   Run Baby Run (Jonah)
# 546      2Vr8KzxFjeDOLV2n9Q9R2H                        Trust Once More
# 547      5p1PlJQPPal10r8tltk5cw                     The Road to Emmaus
# ...                         ...                                    ...
# 1203980  1EFqFwCcNYbocZDekC3SyU                                   Leap
# 1203981  55QIntmvDd7pYpNKl5AK4s                         In The Morning
# 1203982  5sMt9VtgtuakJOUSvVMzhG                                 Hitman
# 1203983  3qgK1i52jyuvz8ATQmMLTx                             Blue Skies
# 1203984  7jLRhH9Wwh7yfMekTdZ3nK  Levitating (feat. DaBaby) - KUU Remix
#
#                                          album                album_id  \
# ...

# %% [markdown]
# This is how I found the latest year of songs collected

# %%
import matplotlib.pyplot as plt

dance_tempos = df.hist(column='tempo')
plt.ylabel('Danceability')
plt.xlabel('Tempo')
plt.title('Danceability of Tempos')

plt.savefig('dance_tempos.jpg')

# %% [markdown]
# This plot shows the distribution of tempos that are most danceable to.
# The most danceable songs have a tempo of roughly 85 to 135.

# %%
for col in df.columns:
    print(col, type(df[col][0]))
# Out:
# id <class 'str'>
# name <class 'str'>
# album <class 'str'>
# album_id <class 'str'>
# artists <class 'str'>
# artist_ids <class 'str'>
# track_number <class 'numpy.int64'>
# disc_number <class 'numpy.int64'>
# explicit <class 'numpy.bool_'>
# danceability <class 'numpy.float64'>
# energy <class 'numpy.float64'>
# key <class 'numpy.int64'>
# loudness <class 'numpy.float64'>
# mode <class 'numpy.int64'>
# speechiness <class 'numpy.float64'>
# acousticness <class 'numpy.float64'>
# instrumentalness <class 'numpy.float64'>
# liveness <class 'numpy.float64'>
# valence <class 'numpy.float64'>
# tempo <class 'numpy.float64'>
# duration_ms <class 'numpy.int64'>
# time_signature <class 'numpy.float64'>
# year <class 'numpy.int64'>
# release_date <class 'str'>

# %% [markdown]
# Found the data types for each attribute

# %%
import matplotlib.pyplot as plt

df['year'] = df['year'].astype('int64')
df.hist(column='year', range=[1900, 2020])
plt.ylabel('danceability')
plt.xlabel('year')
plt.title('Danceability of Songs from 1900 to 2020')

plt.savefig('dance_year.jpg')

# %% [markdown]
# This graph shows the danceability of songs within the years 1900 and 2020

# %%
dance_year = df[['danceability', 'year']]

# %%
dance_year
# Out:
#          danceability  year
# 0               0.470  1999
# 1               0.599  1999
# 2               0.315  1999
# 3               0.440  1999
# 4               0.426  1999
# ...               ...   ...
# 1204020         0.264  2014
# 1204021         0.796  2014
# 1204022         0.785  2014
# 1204023         0.665  2014
# 1204024         0.736  2014
#
# [1204025 rows x 2 columns]

# %% [markdown]
# This table is processed data including only 'danceability' and 'year' values of each song.

# %%
dance_tempo = df[['danceability', 'tempo']]

# %%
dance_tempo
# Out:
#          danceability    tempo
# 0               0.470  117.906
# 1               0.599  103.680
# 2               0.315  149.749
# 3               0.440   96.752
# 4               0.426  127.059
# ...               ...      ...
# 1204020         0.264  159.586
# 1204021         0.796  121.980
# 1204022         0.785  121.996
# 1204023         0.665  124.986
# 1204024         0.736  117.991
#
# [1204025 rows x 2 columns]

# %% [markdown]
# This table is processed data including only 'danceability' and 'tempo' values of each song.

# %%
dance_tempo.to_csv("dance_tempo.csv")

# %%
dance_year.to_csv("dance_year.csv")
